# %%
import pandas_datareader as pdr
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
#Extract Data From API
key = 'f9b723b76349dcbdfd4ecb614b82f4904b7f9c1e'
df = pdr.get_data_tiingo('MSFT', api_key = key)
df.to_csv('MSFT Historical Prices')
df = pd.read_csv('MSFT Historical Prices')
df = pd.DataFrame(df)
df
# Out:
#      symbol                       date   close     high     low    open  \
# 0      MSFT  2015-07-24 00:00:00+00:00   45.94   46.320   45.80   45.91
# 1      MSFT  2015-07-27 00:00:00+00:00   45.35   46.010   45.25   45.94
# 2      MSFT  2015-07-28 00:00:00+00:00   45.34   45.639   44.79   45.58
# 3      MSFT  2015-07-29 00:00:00+00:00   46.29   46.780   45.26   45.40
# 4      MSFT  2015-07-30 00:00:00+00:00   46.88   47.400   45.93   46.26
# ...     ...                        ...     ...      ...     ...     ...
# 1252   MSFT  2020-07-15 00:00:00+00:00  208.04  211.330  205.03  209.56
# 1253   MSFT  2020-07-16 00:00:00+00:00  203.92  205.700  202.31  205.40
# 1254   MSFT  2020-07-17 00:00:00+00:00  202.88  205.040  201.39  204.47
# 1255   MSFT  2020-07-20 00:00:00+00:00  211.60  212.300  203.01  205.00
# 1256   MSFT  2020-07-21 00:00:00+00:00  208.75  213.940  208.03  213.66
#
#         volume    adjClose     adjHigh      adjLow     adjOpen  adjVolume  \
# 0     32333244   41.581320   41.925267   41.454603   41.554167   32333244
# 1     39701420   41.047298   41.644679   40.956786   41.581320   39701420
# 2     34328948   41.038247   41.308878   40.540430   41.255476   34328948
# 3     40945864   41.898113   42.341623   40.965837   41.092554   40945864
# 4     39777883   42.432135   42.902799   41.572269   41.870959   39777883
# ...        ...         ...         ...         ...         ...        ...
# 1252  32248900  208.040000  211.330000  205.030000  209.560000   32248900
# 1253  29940700  203.920000  205.700000  202.310000  205.400000   29940700
# 1254  31636100  202.880000  205.040000  201.390000  204.470000   31636100
# 1255  36386100  211.600000  212.300000  203.010000  205.000000   36386100
# 1256  37702500  208.750000  213.940000  208.030000  213.660000   37702500
#
#       divCash  splitFactor
# 0         0.0          1.0
# 1         0.0          1.0
# 2         0.0          1.0
# 3         0.0          1.0
# 4         0.0          1.0
# ...       ...          ...
# 1252      0.0          1.0
# 1253      0.0          1.0
# 1254      0.0          1.0
# 1255      0.0          1.0
# 1256      0.0          1.0
#
# [1257 rows x 14 columns]

# %%
#Data Clean-up/ Preprocessing 
df.columns = map(lambda x: str(x).capitalize(), df.columns)
df.rename(columns = {'Close price': 'Close'}, inplace = True)
df.shape # 1257 trading days in dataset 
df['Date'] = pd.to_datetime(df['Date']).dt.date
df.dropna() #drop all n/a values 
null_check = df.isnull()
#Checking for Missing Values
for column in null_check.columns.values.tolist():
    print (null_check[column].value_counts())  
df
# Out:
# False    1257
# Name: Symbol, dtype: int64
# False    1257
# Name: Date, dtype: int64
# False    1257
# Name: Close, dtype: int64
# False    1257
# Name: High, dtype: int64
# False    1257
# Name: Low, dtype: int64
# False    1257
# Name: Open, dtype: int64
# False    1257
# Name: Volume, dtype: int64
# False    1257
# Name: Adjclose, dtype: int64
# False    1257
# Name: Adjhigh, dtype: int64
# False    1257
# Name: Adjlow, dtype: int64
# False    1257
# Name: Adjopen, dtype: int64
# False    1257
# Name: Adjvolume, dtype: int64
# False    1257
# Name: Divcash, dtype: int64
# False    1257
# Name: Splitfactor, dtype: int64
#      Symbol        Date   Close     High     Low    Open    Volume  \
# 0      MSFT  2015-07-24   45.94   46.320   45.80   45.91  32333244
# 1      MSFT  2015-07-27   45.35   46.010   45.25   45.94  39701420
# 2      MSFT  2015-07-28   45.34   45.639   44.79   45.58  34328948
# 3      MSFT  2015-07-29   46.29   46.780   45.26   45.40  40945864
# 4      MSFT  2015-07-30   46.88   47.400   45.93   46.26  39777883
# ...     ...         ...     ...      ...     ...     ...       ...
# 1252   MSFT  2020-07-15  208.04  211.330  205.03  209.56  32248900
# 1253   MSFT  2020-07-16  203.92  205.700  202.31  205.40  29940700
# 1254   MSFT  2020-07-17  202.88  205.040  201.39  204.47  31636100
# 1255   MSFT  2020-07-20  211.60  212.300  203.01  205.00  36386100
# 1256   MSFT  2020-07-21  208.75  213.940  208.03  213.66  37702500
#
#         Adjclose     Adjhigh      Adjlow     Adjopen  Adjvolume  Divcash  \
# 0      41.581320   41.925267   41.454603   41.554167   32333244      0.0
# 1      41.047298   41.644679   40.956786   41.581320   39701420      0.0
# 2      41.038247   41.308878   40.540430   41.255476   34328948      0.0
# 3      41.898113   42.341623   40.965837   41.092554   40945864      0.0
# 4      42.432135   42.902799   41.572269   41.870959   39777883      0.0
# ...          ...         ...         ...         ...        ...      ...
# 1252  208.040000  211.330000  205.030000  209.560000   32248900      0.0
# 1253  203.920000  205.700000  202.310000  205.400000   29940700      0.0
# 1254  202.880000  205.040000  201.390000  204.470000   31636100      0.0
# 1255  211.600000  212.300000  203.010000  205.000000   36386100      0.0
# 1256  208.750000  213.940000  208.030000  213.660000   37702500      0.0
#
#       Splitfactor
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 1252          1.0
# 1253          1.0
# 1254          1.0
# 1255          1.0
# 1256          1.0
#
# [1257 rows x 14 columns]

# %%
#Visualizing Closing Price History 
df_plot_close = df[['Close', 'Date']]
df_plot_close.plot(kind = 'line', x = 'Date', y = 'Close')
plt.gcf().set_size_inches(12, 8)
plt.title('Historical MSFT Close Price')
plt.xlabel('Date')
plt.ylabel('Price ($)')
# Out:
# Text(0, 0.5, 'Price ($)')

# %%
#Normalization - MinMaxScaler
df_close = df[['Close', 'Date']]
df_close.set_index('Date', inplace = True)
mms = MinMaxScaler(feature_range = (0,1))
scaled_close = mms.fit_transform(df_close).reshape(-1,1)

# %%
#Splitting Train vs Test Data
train_ratio = 0.80
rolling = 60
train_data = np.array(scaled_close[:int(len(df_close)*train_ratio)])
test_data = np.array(scaled_close[int(len(train_data))-rolling:])

#Shapes
traind_shape = train_data.shape
tstd_shape = test_data.shape 
traind_shape, tstd_shape
# Out:
# ((1005, 1), (312, 1))

# %%
#Seperating x/y Training Sets
x_train = []
y_train = []
for i in range(rolling, len(train_data)):
    x_train.append(train_data[i-rolling:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train_shape = x_train.shape[0]
x_train = np.reshape(x_train, (x_train_shape, rolling, 1))
y_train = np.reshape(y_train, (-1,1))

# %%
#Seperating x/y Testing Sets
x_test = []
y_test = df_close[int(len(train_data)):]
for i in range(rolling, len(test_data)):
    x_test.append(test_data[i-rolling:i])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test_shape = x_test.shape[0]
x_test = np.reshape(x_test, (x_test_shape, rolling, 1))
y_test = np.reshape(y_test, (-1,1))

# %%
#LSTM Model
lstm = Sequential()
lstm.add(LSTM(rolling, return_sequences = True, input_shape = (rolling, 1)))
lstm.add(LSTM(rolling, return_sequences = True))
lstm.add(LSTM(rolling))
lstm.add(Dense(1))
lstm.compile(optimizer = 'adam', loss = 'mse', metrics = ['mean_squared_error'])

# %%
#LSTM Model Summary
lstm.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_24 (LSTM)               (None, 60, 60)            14880
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 60, 60)            29040
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 60)                29040
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 61
# =================================================================
# Total params: 73,021
# Trainable params: 73,021
# Non-trainable params: 0
# _________________________________________________________________

# %%
#LSTM Model Fitting
lstm.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=rolling,batch_size=64,verbose=1)
# Out:
# Epoch 1/60
# 15/15 [==============================] - 2s 149ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 26399.9785 - val_mean_squared_error: 26399.9785
# Epoch 2/60
# 15/15 [==============================] - 1s 95ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 26347.2812 - val_mean_squared_error: 26347.2812
# Epoch 3/60
# 15/15 [==============================] - 1s 98ms/step - loss: 4.2577e-04 - mean_squared_error: 4.2577e-04 - val_loss: 26332.5156 - val_mean_squared_error: 26332.5156
# Epoch 4/60
# 15/15 [==============================] - 1s 95ms/step - loss: 2.8760e-04 - mean_squared_error: 2.8760e-04 - val_loss: 26332.3730 - val_mean_squared_error: 26332.3730
# Epoch 5/60
# 15/15 [==============================] - 1s 95ms/step - loss: 2.3322e-04 - mean_squared_error: 2.3322e-04 - val_loss: 26336.3223 - val_mean_squared_error: 26336.3223
# Epoch 6/60
# 15/15 [==============================] - 1s 95ms/step - loss: 2.2279e-04 - mean_squared_error: 2.2279e-04 - val_loss: 26339.6816 - val_mean_squared_error: 26339.6816
# Epoch 7/60
# 15/15 [==============================] - 1s 90ms/step - loss: 2.1703e-04 - mean_squared_error: 2.1703e-04 - val_loss: 26336.4883 - val_mean_squared_error: 26336.4883
# Epoch 8/60
# 15/15 [==============================] - 1s 94ms/step - loss: 2.2948e-04 - mean_squared_error: 2.2948e-04 - val_loss: 26332.8184 - val_mean_squared_error: 26332.8184
# Epoch 9/60
# 15/15 [==============================] - 1s 94ms/step - loss: 2.2485e-04 - mean_squared_error: 2.2485e-04 - val_loss: 26336.6699 - val_mean_squared_error: 26336.6699
# Epoch 10/60
# 15/15 [==============================] - 1s 95ms/step - loss: 2.2516e-04 - mean_squared_error: 2.2516e-04 - val_loss: 26332.9199 - val_mean_squared_error: 26332.9199
# Epoch 11/60
# 15/15 [==============================] - 1s 94ms/step - loss: 2.2256e-04 - mean_squared_error: 2.2256e-04 - val_loss: 26333.9883 - val_mean_squared_error: 26333.9883
# Epoch 12/60
# 15/15 [==============================] - 1s 94ms/step - loss: 2.1848e-04 - mean_squared_error: 2.1848e-04 - val_loss: 26341.9004 - val_mean_squared_error: 26341.9004
# Epoch 13/60
# 15/15 [==============================] - 2s 117ms/step - loss: 2.2012e-04 - mean_squared_error: 2.2012e-04 - val_loss: 26340.6250 - val_mean_squared_error: 26340.6250
# Epoch 14/60
# 15/15 [==============================] - 2s 112ms/step - loss: 2.1216e-04 - mean_squared_error: 2.1216e-04 - val_loss: 26338.4688 - val_mean_squared_error: 26338.4688
# Epoch 15/60
# 15/15 [==============================] - 2s 120ms/step - loss: 2.1282e-04 - mean_squared_error: 2.1282e-04 - val_loss: 26338.3770 - val_mean_squared_error: 26338.3770
# Epoch 16/60
# 15/15 [==============================] - 2s 104ms/step - loss: 2.1016e-04 - mean_squared_error: 2.1016e-04 - val_loss: 26332.9102 - val_mean_squared_error: 26332.9102
# Epoch 17/60
# 15/15 [==============================] - 1s 95ms/step - loss: 2.1971e-04 - mean_squared_error: 2.1971e-04 - val_loss: 26338.0684 - val_mean_squared_error: 26338.0684
# Epoch 18/60
# 15/15 [==============================] - 1s 88ms/step - loss: 2.0369e-04 - mean_squared_error: 2.0369e-04 - val_loss: 26335.4414 - val_mean_squared_error: 26335.4414
# Epoch 19/60
# 15/15 [==============================] - 1s 95ms/step - loss: 2.1485e-04 - mean_squared_error: 2.1485e-04 - val_loss: 26339.3379 - val_mean_squared_error: 26339.3379
# Epoch 20/60
# 15/15 [==============================] - 1s 94ms/step - loss: 2.0574e-04 - mean_squared_error: 2.0574e-04 - val_loss: 26340.6797 - val_mean_squared_error: 26340.6797
# Epoch 21/60
# 15/15 [==============================] - 1s 87ms/step - loss: 2.2942e-04 - mean_squared_error: 2.2942e-04 - val_loss: 26340.8906 - val_mean_squared_error: 26340.8906
# Epoch 22/60
# 15/15 [==============================] - 1s 93ms/step - loss: 2.2036e-04 - mean_squared_error: 2.2036e-04 - val_loss: 26342.6348 - val_mean_squared_error: 26342.6348
# Epoch 23/60
# 15/15 [==============================] - 1s 95ms/step - loss: 2.2572e-04 - mean_squared_error: 2.2572e-04 - val_loss: 26341.1797 - val_mean_squared_error: 26341.1797
# Epoch 24/60
# 15/15 [==============================] - 1s 94ms/step - loss: 2.3593e-04 - mean_squared_error: 2.3593e-04 - val_loss: 26339.4844 - val_mean_squared_error: 26339.4844
# Epoch 25/60
# 15/15 [==============================] - 1s 98ms/step - loss: 2.2947e-04 - mean_squared_error: 2.2947e-04 - val_loss: 26332.2930 - val_mean_squared_error: 26332.2930
# Epoch 26/60
# 15/15 [==============================] - 2s 104ms/step - loss: 2.1351e-04 - mean_squared_error: 2.1351e-04 - val_loss: 26337.8223 - val_mean_squared_error: 26337.8223
# Epoch 27/60
# 15/15 [==============================] - 2s 108ms/step - loss: 1.9611e-04 - mean_squared_error: 1.9611e-04 - val_loss: 26343.4043 - val_mean_squared_error: 26343.4043
# Epoch 28/60
# 15/15 [==============================] - 2s 106ms/step - loss: 2.0688e-04 - mean_squared_error: 2.0688e-04 - val_loss: 26340.1094 - val_mean_squared_error: 26340.1094
# Epoch 29/60
# 15/15 [==============================] - 2s 121ms/step - loss: 2.1659e-04 - mean_squared_error: 2.1659e-04 - val_loss: 26341.2949 - val_mean_squared_error: 26341.2949
# Epoch 30/60
# 15/15 [==============================] - 1s 99ms/step - loss: 2.0702e-04 - mean_squared_error: 2.0702e-04 - val_loss: 26337.3730 - val_mean_squared_error: 26337.3730
# Epoch 31/60
# 15/15 [==============================] - 2s 108ms/step - loss: 1.9386e-04 - mean_squared_error: 1.9386e-04 - val_loss: 26341.0918 - val_mean_squared_error: 26341.0918
# Epoch 32/60
# 15/15 [==============================] - 2s 104ms/step - loss: 2.2141e-04 - mean_squared_error: 2.2141e-04 - val_loss: 26340.7031 - val_mean_squared_error: 26340.7031
# Epoch 33/60
# 15/15 [==============================] - 2s 109ms/step - loss: 1.9363e-04 - mean_squared_error: 1.9363e-04 - val_loss: 26343.0117 - val_mean_squared_error: 26343.0117
# Epoch 34/60
# 15/15 [==============================] - 2s 139ms/step - loss: 2.0889e-04 - mean_squared_error: 2.0889e-04 - val_loss: 26345.2520 - val_mean_squared_error: 26345.2520
# Epoch 35/60
# 15/15 [==============================] - 2s 126ms/step - loss: 1.9686e-04 - mean_squared_error: 1.9686e-04 - val_loss: 26335.3379 - val_mean_squared_error: 26335.3379
# Epoch 36/60
# 15/15 [==============================] - 2s 107ms/step - loss: 1.8704e-04 - mean_squared_error: 1.8704e-04 - val_loss: 26339.5273 - val_mean_squared_error: 26339.5273
# Epoch 37/60
# 15/15 [==============================] - 2s 106ms/step - loss: 1.8488e-04 - mean_squared_error: 1.8488e-04 - val_loss: 26338.7402 - val_mean_squared_error: 26338.7402
# Epoch 38/60
# 15/15 [==============================] - 2s 105ms/step - loss: 1.8079e-04 - mean_squared_error: 1.8079e-04 - val_loss: 26338.4609 - val_mean_squared_error: 26338.4609
# Epoch 39/60
# 15/15 [==============================] - 2s 113ms/step - loss: 1.8289e-04 - mean_squared_error: 1.8289e-04 - val_loss: 26339.9961 - val_mean_squared_error: 26339.9961
# Epoch 40/60
# 15/15 [==============================] - 2s 108ms/step - loss: 1.8001e-04 - mean_squared_error: 1.8001e-04 - val_loss: 26338.8008 - val_mean_squared_error: 26338.8008
# Epoch 41/60
# 15/15 [==============================] - 2s 109ms/step - loss: 1.8875e-04 - mean_squared_error: 1.8875e-04 - val_loss: 26335.0703 - val_mean_squared_error: 26335.0703
# Epoch 42/60
# 15/15 [==============================] - 2s 107ms/step - loss: 1.8747e-04 - mean_squared_error: 1.8747e-04 - val_loss: 26334.3047 - val_mean_squared_error: 26334.3047
# Epoch 43/60
# 15/15 [==============================] - 2s 102ms/step - loss: 1.8083e-04 - mean_squared_error: 1.8083e-04 - val_loss: 26340.7695 - val_mean_squared_error: 26340.7695
# Epoch 44/60
# 15/15 [==============================] - 2s 109ms/step - loss: 1.7742e-04 - mean_squared_error: 1.7742e-04 - val_loss: 26339.9102 - val_mean_squared_error: 26339.9102
# Epoch 45/60
# 15/15 [==============================] - 2s 112ms/step - loss: 1.8254e-04 - mean_squared_error: 1.8254e-04 - val_loss: 26338.0547 - val_mean_squared_error: 26338.0547
# Epoch 46/60
# 15/15 [==============================] - 2s 105ms/step - loss: 1.7451e-04 - mean_squared_error: 1.7451e-04 - val_loss: 26335.1113 - val_mean_squared_error: 26335.1113
# Epoch 47/60
# 15/15 [==============================] - 2s 115ms/step - loss: 1.6965e-04 - mean_squared_error: 1.6965e-04 - val_loss: 26338.8789 - val_mean_squared_error: 26338.8789
# Epoch 48/60
# 15/15 [==============================] - 2s 118ms/step - loss: 1.7078e-04 - mean_squared_error: 1.7078e-04 - val_loss: 26335.5117 - val_mean_squared_error: 26335.5117
# Epoch 49/60
# 15/15 [==============================] - 2s 121ms/step - loss: 1.7118e-04 - mean_squared_error: 1.7118e-04 - val_loss: 26331.8496 - val_mean_squared_error: 26331.8496
# Epoch 50/60
# 15/15 [==============================] - 2s 121ms/step - loss: 1.7059e-04 - mean_squared_error: 1.7059e-04 - val_loss: 26341.3496 - val_mean_squared_error: 26341.3496
# Epoch 51/60
# 15/15 [==============================] - 2s 116ms/step - loss: 1.7515e-04 - mean_squared_error: 1.7515e-04 - val_loss: 26337.5508 - val_mean_squared_error: 26337.5508
# Epoch 52/60
# 15/15 [==============================] - 2s 119ms/step - loss: 1.9224e-04 - mean_squared_error: 1.9224e-04 - val_loss: 26345.4023 - val_mean_squared_error: 26345.4023
# Epoch 53/60
# 15/15 [==============================] - 2s 118ms/step - loss: 1.8160e-04 - mean_squared_error: 1.8160e-04 - val_loss: 26330.1309 - val_mean_squared_error: 26330.1309
# Epoch 54/60
# 15/15 [==============================] - 2s 103ms/step - loss: 2.0396e-04 - mean_squared_error: 2.0396e-04 - val_loss: 26342.5977 - val_mean_squared_error: 26342.5977
# Epoch 55/60
# 15/15 [==============================] - 2s 101ms/step - loss: 1.7307e-04 - mean_squared_error: 1.7307e-04 - val_loss: 26338.7930 - val_mean_squared_error: 26338.7930
# Epoch 56/60
# 15/15 [==============================] - 2s 118ms/step - loss: 1.7124e-04 - mean_squared_error: 1.7124e-04 - val_loss: 26339.3223 - val_mean_squared_error: 26339.3223
# Epoch 57/60
# 15/15 [==============================] - 2s 121ms/step - loss: 1.6197e-04 - mean_squared_error: 1.6197e-04 - val_loss: 26338.1738 - val_mean_squared_error: 26338.1738
# Epoch 58/60
# 15/15 [==============================] - 2s 107ms/step - loss: 1.7499e-04 - mean_squared_error: 1.7499e-04 - val_loss: 26339.4004 - val_mean_squared_error: 26339.4004
# Epoch 59/60
# 15/15 [==============================] - 2s 122ms/step - loss: 1.7139e-04 - mean_squared_error: 1.7139e-04 - val_loss: 26338.8965 - val_mean_squared_error: 26338.8965
# Epoch 60/60
# 15/15 [==============================] - 2s 119ms/step - loss: 1.7724e-04 - mean_squared_error: 1.7724e-04 - val_loss: 26335.3652 - val_mean_squared_error: 26335.3652

# %%
#Train/ Test Data Predictions
x_train_p = lstm.predict(x_train)
x_test_p = lstm.predict(x_test)

# %%
#Rescaling Data
x_train_p = mms.inverse_transform(x_train_p)
x_test_p = mms.inverse_transform(x_test_p)
y_train_scaled = mms.inverse_transform(y_train)

# %%
training_train = df_close[rolling:int(len(train_data))]
training_train['Predicted Close'] = x_train_p
plt.figure(figsize = (16,8))
plt.title('MSFT Equity Price v.s Predicted')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.plot(training_train['Close'])
plt.plot(training_train[['Predicted Close']])
plt.legend(['Training Data', 'Validation'])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Training Model Valuation (RMSE, MSE, R^2)
MSE = np.mean(x_train_p - y_train_scaled)**2
RMSE = np.sqrt(MSE)
R2 = r2_score(x_train_p, y_train_scaled)
print ('Mean Squared Error:', MSE, '\nRoot Mean Squared Error:', RMSE, '\nR^2:', R2)
# Out:
# Mean Squared Error: 0.3289111326559434
# Root Mean Squared Error: 0.5735077441987539
# R^2: 0.9923859580986124

# %%
training_train = df_close[rolling:int(len(train_data))]
training_train['Predicted Close'] = x_train_p
validation = df_close[int(len(train_data)):]
validation['Predicted Close'] = x_test_p
plt.figure(figsize = (16,8))
plt.title('LSTM Model (MSFT Prices)')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.plot(training_train['Close'])
plt.plot(training_train[['Predicted Close']])
plt.plot(validation['Close'])
plt.plot(validation['Predicted Close'])
plt.legend(['Training Data', 'Training Validation', 'Test Data', 'Testing Validation' ])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#Training Model Valuation (RMSE, MSE, R^2)
MSE = np.mean(x_test_p - y_test)**2
RMSE = np.sqrt(MSE)
R2 = r2_score(x_test_p, y_test)
print ('Mean Squared Error:', MSE, '\nRoot Mean Squared Error:', RMSE, '\nR^2:', R2)
# Out:
# Mean Squared Error: 0.06913247398798947
# Root Mean Squared Error: 0.26293054974268293
# R^2: 0.9109781816759812

# %%
#Retrain Using Whole Test Data
df_final = np.array(scaled_close)
x = []
y = []
train_amt = 60
for i in range(train_amt, len(df_final)):
    x.append(df_final[i-train_amt:i,0])
    y.append(df_final[i,0])
x, y = np.array(x), np.array(y)
x_shape = x.shape[0]
x = np.reshape(x, (x_shape, train_amt, 1))
y = np.reshape(y, (-1,1))

# %%
#LSTM Model #2
lstm_all = Sequential()
lstm_all.add(LSTM(train_amt, return_sequences = True, input_shape = (rolling, 1)))
lstm_all.add(LSTM(train_amt, return_sequences = True))
lstm_all.add(LSTM(train_amt))
lstm_all.add(Dense(1))
lstm_all.compile(optimizer = 'adam', loss = 'mse', metrics = ['mean_squared_error'])

# %%
#LSTM Model #2 Fitting
lstm_all.fit(x,y,epochs=train_amt,batch_size=64,verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 2s 91ms/step - loss: 0.0358 - mean_squared_error: 0.0358
# Epoch 2/60
# 19/19 [==============================] - 2s 94ms/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 3/60
# 19/19 [==============================] - 2s 103ms/step - loss: 9.5903e-04 - mean_squared_error: 9.5903e-04
# Epoch 4/60
# 19/19 [==============================] - 2s 89ms/step - loss: 7.9196e-04 - mean_squared_error: 7.9196e-04
# Epoch 5/60
# 19/19 [==============================] - 2s 87ms/step - loss: 7.6112e-04 - mean_squared_error: 7.6112e-04
# Epoch 6/60
# 19/19 [==============================] - 2s 89ms/step - loss: 7.5311e-04 - mean_squared_error: 7.5311e-04
# Epoch 7/60
# 19/19 [==============================] - 2s 88ms/step - loss: 7.6231e-04 - mean_squared_error: 7.6231e-04
# Epoch 8/60
# 19/19 [==============================] - 2s 91ms/step - loss: 6.9496e-04 - mean_squared_error: 6.9496e-04
# Epoch 9/60
# 19/19 [==============================] - 2s 96ms/step - loss: 6.8132e-04 - mean_squared_error: 6.8132e-04
# Epoch 10/60
# 19/19 [==============================] - 3s 133ms/step - loss: 6.7892e-04 - mean_squared_error: 6.7892e-04
# Epoch 11/60
# 19/19 [==============================] - 2s 126ms/step - loss: 6.9802e-04 - mean_squared_error: 6.9802e-04
# Epoch 12/60
# 19/19 [==============================] - 3s 135ms/step - loss: 7.4930e-04 - mean_squared_error: 7.4930e-04
# Epoch 13/60
# 19/19 [==============================] - 2s 120ms/step - loss: 6.7734e-04 - mean_squared_error: 6.7734e-04
# Epoch 14/60
# 19/19 [==============================] - 2s 104ms/step - loss: 7.2934e-04 - mean_squared_error: 7.2934e-04
# Epoch 15/60
# 19/19 [==============================] - 2s 120ms/step - loss: 6.7412e-04 - mean_squared_error: 6.7412e-04
# Epoch 16/60
# 19/19 [==============================] - 2s 120ms/step - loss: 9.8036e-04 - mean_squared_error: 9.8036e-04
# Epoch 17/60
# 19/19 [==============================] - 2s 104ms/step - loss: 6.6197e-04 - mean_squared_error: 6.6197e-04
# Epoch 18/60
# 19/19 [==============================] - 2s 123ms/step - loss: 5.8006e-04 - mean_squared_error: 5.8006e-04
# Epoch 19/60
# 19/19 [==============================] - 2s 116ms/step - loss: 5.8735e-04 - mean_squared_error: 5.8735e-04
# Epoch 20/60
# 19/19 [==============================] - 2s 100ms/step - loss: 5.6420e-04 - mean_squared_error: 5.6420e-04
# Epoch 21/60
# 19/19 [==============================] - 2s 101ms/step - loss: 5.6914e-04 - mean_squared_error: 5.6914e-04
# Epoch 22/60
# 19/19 [==============================] - 2s 99ms/step - loss: 5.9784e-04 - mean_squared_error: 5.9784e-04
# Epoch 23/60
# 19/19 [==============================] - 2s 99ms/step - loss: 6.4868e-04 - mean_squared_error: 6.4868e-04
# Epoch 24/60
# 19/19 [==============================] - 2s 100ms/step - loss: 5.5092e-04 - mean_squared_error: 5.5092e-04
# Epoch 25/60
# 19/19 [==============================] - 2s 97ms/step - loss: 5.7591e-04 - mean_squared_error: 5.7591e-04
# Epoch 26/60
# 19/19 [==============================] - 2s 103ms/step - loss: 5.2092e-04 - mean_squared_error: 5.2092e-04
# Epoch 27/60
# 19/19 [==============================] - 2s 98ms/step - loss: 4.5750e-04 - mean_squared_error: 4.5750e-04
# Epoch 28/60
# 19/19 [==============================] - 2s 101ms/step - loss: 5.0797e-04 - mean_squared_error: 5.0797e-04
# Epoch 29/60
# 19/19 [==============================] - 2s 101ms/step - loss: 4.5286e-04 - mean_squared_error: 4.5286e-04
# Epoch 30/60
# 19/19 [==============================] - 2s 98ms/step - loss: 4.2665e-04 - mean_squared_error: 4.2665e-04
# Epoch 31/60
# 19/19 [==============================] - 2s 100ms/step - loss: 3.8733e-04 - mean_squared_error: 3.8733e-04
# Epoch 32/60
# 19/19 [==============================] - 2s 101ms/step - loss: 4.0343e-04 - mean_squared_error: 4.0343e-04
# Epoch 33/60
# 19/19 [==============================] - 2s 101ms/step - loss: 5.1818e-04 - mean_squared_error: 5.1818e-04
# Epoch 34/60
# 19/19 [==============================] - 2s 100ms/step - loss: 3.8387e-04 - mean_squared_error: 3.8387e-04
# Epoch 35/60
# 19/19 [==============================] - 2s 100ms/step - loss: 3.4686e-04 - mean_squared_error: 3.4686e-04
# Epoch 36/60
# 19/19 [==============================] - 2s 97ms/step - loss: 3.6537e-04 - mean_squared_error: 3.6537e-04
# Epoch 37/60
# 19/19 [==============================] - 2s 103ms/step - loss: 3.7116e-04 - mean_squared_error: 3.7116e-04
# Epoch 38/60
# 19/19 [==============================] - 2s 104ms/step - loss: 3.4413e-04 - mean_squared_error: 3.4413e-04
# Epoch 39/60
# 19/19 [==============================] - 2s 99ms/step - loss: 3.3851e-04 - mean_squared_error: 3.3851e-04
# Epoch 40/60
# 19/19 [==============================] - 2s 102ms/step - loss: 3.9596e-04 - mean_squared_error: 3.9596e-04
# Epoch 41/60
# 19/19 [==============================] - 2s 104ms/step - loss: 3.9757e-04 - mean_squared_error: 3.9757e-04
# Epoch 42/60
# 19/19 [==============================] - 2s 102ms/step - loss: 4.5321e-04 - mean_squared_error: 4.5321e-04
# Epoch 43/60
# 19/19 [==============================] - 2s 97ms/step - loss: 4.1636e-04 - mean_squared_error: 4.1636e-04
# Epoch 44/60
# 19/19 [==============================] - 2s 92ms/step - loss: 3.7224e-04 - mean_squared_error: 3.7224e-04
# Epoch 45/60
# 19/19 [==============================] - 2s 102ms/step - loss: 3.5263e-04 - mean_squared_error: 3.5263e-04
# Epoch 46/60
# 19/19 [==============================] - 2s 101ms/step - loss: 3.3623e-04 - mean_squared_error: 3.3623e-04
# Epoch 47/60
# 19/19 [==============================] - 2s 97ms/step - loss: 3.9546e-04 - mean_squared_error: 3.9546e-04
# Epoch 48/60
# 19/19 [==============================] - 2s 100ms/step - loss: 3.3473e-04 - mean_squared_error: 3.3473e-04
# Epoch 49/60
# 19/19 [==============================] - 2s 100ms/step - loss: 3.0730e-04 - mean_squared_error: 3.0730e-04
# Epoch 50/60
# 19/19 [==============================] - 2s 100ms/step - loss: 3.4596e-04 - mean_squared_error: 3.4596e-04
# Epoch 51/60
# 19/19 [==============================] - 2s 96ms/step - loss: 3.3182e-04 - mean_squared_error: 3.3182e-04
# Epoch 52/60
# 19/19 [==============================] - 2s 105ms/step - loss: 4.5865e-04 - mean_squared_error: 4.5865e-04
# Epoch 53/60
# 19/19 [==============================] - 2s 98ms/step - loss: 3.8625e-04 - mean_squared_error: 3.8625e-04
# Epoch 54/60
# 19/19 [==============================] - 2s 97ms/step - loss: 3.5167e-04 - mean_squared_error: 3.5167e-04
# Epoch 55/60
# 19/19 [==============================] - 2s 98ms/step - loss: 4.1177e-04 - mean_squared_error: 4.1177e-04
# Epoch 56/60
# 19/19 [==============================] - 2s 101ms/step - loss: 3.3654e-04 - mean_squared_error: 3.3654e-04
# Epoch 57/60
# 19/19 [==============================] - 2s 97ms/step - loss: 3.1427e-04 - mean_squared_error: 3.1427e-04
# Epoch 58/60
# 19/19 [==============================] - 2s 100ms/step - loss: 3.3142e-04 - mean_squared_error: 3.3142e-04
# Epoch 59/60
# 19/19 [==============================] - 2s 99ms/step - loss: 3.3234e-04 - mean_squared_error: 3.3234e-04
# Epoch 60/60
# 19/19 [==============================] - 2s 98ms/step - loss: 2.8998e-04 - mean_squared_error: 2.8998e-04

# %%
#Projection Set
steps = 20
df_final = pd.DataFrame(scaled_close)
for x in range (0,steps):
    data = np.array(df_final[len(df_final)-train_amt + x:])
    x_project = np.array(data)
    x_project_shape = x_project.shape[0]
    x_project = np.reshape(x_project, (1, -1, 1))
    projected_data = pd.DataFrame(lstm_all.predict(x_project))
    df_final = df_final.append(projected_data)

# %%
#Rescaling the Dataset
df_final = mms.inverse_transform(df_final)

# %%
#Creating a Function For Adding Business Days
import datetime
def add_bdays(from_date, add_days):
    bdays_add = add_days
    curr_date = from_date
    while bdays_add > 0:
        curr_date += datetime.timedelta(days=1)
        weekday = curr_date.weekday()
        if weekday >= 5: 
            continue
        bdays_add -= 1
    return curr_date

# %%
#Creating Date Index With 10 Days Forward 
df_date = df[['Date']]
start_date = str(df_date['Date'][0])
end_date = df_date['Date'].iloc[-1]
proj_dates = []
for x in range(1,steps+1):
    proj_dates.append(add_bdays(end_date,x))
df_proj_dates = pd.DataFrame(proj_dates)
df_append_date = df_date['Date'].append(df_proj_dates)
date_array = np.array(df_append_date)
date_array.shape, df_final.shape
# Out:
# ((1277, 1), (1277, 1))

# %%
#Creating New DataFrame For Forward Dates
df_new = pd.DataFrame(df_final, columns=['Projected Close'])
df_new['Date'] = date_array
df_new.set_index('Date', inplace = True)
projected_df = df_new.tail(steps)
projected_df
# Out:
#             Projected Close
# Date
# 2020-07-22       204.919714
# 2020-07-23       203.673040
# 2020-07-24       202.478726
# 2020-07-27       201.283791
# 2020-07-28       200.071644
# 2020-07-29       198.849974
# 2020-07-30       197.638677
# 2020-07-31       196.462590
# 2020-08-03       195.347714
# 2020-08-04       194.317404
# 2020-08-05       193.391577
# 2020-08-06       192.586377
# 2020-08-07       191.914612
# 2020-08-10       191.384903
# 2020-08-11       191.001872
# 2020-08-12       190.766151
# 2020-08-13       190.672829
# 2020-08-14       190.715573
# 2020-08-17       190.876427
# 2020-08-18       191.134914

# %%
#Projected Values
plt.figure(figsize = (16,8))
plt.title('MSFT Equity Prices')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.plot(df_close.iloc[-rolling:-1])
plt.plot(projected_df)
plt.legend(['Historical Prices', 'Projected Prices'])
plt.show()
